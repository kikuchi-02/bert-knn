# %%
import utils

# %%
df = utils.read_data('dataset/ja/shinzo_abe.csv')
df.head()
# Out:
#                              url Full Name Show Username Dir Tweet Nav  \
# 0  https://twitter.com/AbeShinzo           安倍晋三    AbeShinzo    Oct 21
# 1  https://twitter.com/AbeShinzo           安倍晋三    AbeShinzo    Oct 20
# 2  https://twitter.com/AbeShinzo           安倍晋三    AbeShinzo    Oct 20
# 3  https://twitter.com/AbeShinzo           安倍晋三    AbeShinzo    Oct 19
# 4  https://twitter.com/AbeShinzo           安倍晋三    AbeShinzo    Oct 19
#
#                                       Tweet Nav_link  \
# 0  https://twitter.com/AbeShinzo/status/921745765...
# 1  https://twitter.com/AbeShinzo/status/921350545...
# 2  https://twitter.com/AbeShinzo/status/921322049...
# 3  https://twitter.com/AbeShinzo/status/920998741...
# 4  https://twitter.com/AbeShinzo/status/920991367...
#
#                                Tweet Text Size Block  \
# 0  選挙期間中、自民党の候補者たちは全国各地で我々の経済政策を、安全保障を、そして日本の将来を担...
# 1  外国人旅行者数はこの５年間で３倍になりました。自民党は高次元での観光資源施策に取り組み我が国...
# 2  明日１０月２１日(土) 安倍晋三総裁は岐阜県、愛知県、東京都に参ります。 詳細は是非、自民党...
# 3  我々がスタートした返さなくても良い「給付型奨学金」や「授業料免除」といった制度を拡充し、真に...
# 4  明日１０月２０日(金) 安倍晋三総裁は神奈川県、東京都に参ります。 詳細は是非、自民党の特設...
#
#                                 Tweet Text Size Link  \
# 0  https://twitter.com/jimin_koho/status/92174405...
# 1                         pic.twitter.com/EMNDcADrYB
# 2                          https://special.jimin.jp/
# 3                         pic.twitter.com/ZgAYDhlzDD
# 4                          https://special.jimin.jp/
#
#   Tweet Text Size Link_link Profile Tweet 1 Profile Tweet 2 Profile Tweet 3  \
# 0   https://t.co/HVjFn3QJp5   1,133 replies  5,752 retweets    14,514 likes
# 1   https://t.co/EMNDcADrYB     606 replies  3,712 retweets     8,946 likes
# 2   https://t.co/vKXI8z5Mjr     358 replies  2,213 retweets     4,922 likes
# 3   https://t.co/ZgAYDhlzDD     456 replies  3,081 retweets     6,576 likes
# 4   https://t.co/vKXI8z5Mjr     271 replies  2,291 retweets     5,610 likes
#
#   Reply Re Tweet  Like
# 0  1.1K     5.8K   15K
# 1   606     3.7K  8.9K
# 2   358     2.2K  4.9K
# 3   456     3.1K  6.6K
# 4   271     2.3K  5.6K

# %%
tweet = list(df.loc[:, 'Tweet Text Size Block'])
vecs = utils.bert_encode(tweet)
ids = utils.get_near(vecs, vecs[0])
# Out:
# start encoding
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-edb06e096540> in <module>
#       1 tweet = list(df.loc[:, 'Tweet Text Size Block'])
# ----> 2 vecs = utils.bert_encode(tweet)
#       3 ids = utils.get_near(vecs, vecs[0])
#
# ~/selfTaught/dataScience/bert-knn/utils.py in bert_encode(text_list, is_tokenized)
#      21     print('start encoding')
#      22     start = time.time()
# ---> 23     bc = BertClient()
#      24     vec_list = bc.encode(text_list, is_tokenized)
#      25     end = time.time()
#
# ~/.pyenv/versions/3.6.5/envs/bert_client_api/lib/python3.6/site-packages/bert_serving/client/__init__.py in __init__(self, ip, port, port_out, output_fmt, show_server_config, identity, check_version, check_length, check_token_info, ignore_all_checks, timeout)
#     106
#     107         if not ignore_all_checks and (check_version or show_server_config or check_length or check_token_info):
# --> 108             s_status = self.server_config
#     109
#     110             if check_version and s_status['server_version'] != self.status['client_version']:
#
# ~/.pyenv/versions/3.6.5/envs/bert_client_api/lib/python3.6/site-packages/bert_serving/client/__init__.py in arg_wrapper(self, *args, **kwargs)
#     204                 self.receiver.setsockopt(zmq.RCVTIMEO, self.timeout)
#     205             try:
# --> 206                 return func(self, *args, **kwargs)
#     207             except zmq.error.Again as _e:
#     208                 t_e = TimeoutError(
#
# ~/.pyenv/versions/3.6.5/envs/bert_client_api/lib/python3.6/site-packages/bert_serving/client/__init__.py in server_config(self)
#     230         """
#     231         req_id = self._send(b'SHOW_CONFIG')
# --> 232         return jsonapi.loads(self._recv(req_id).content[1])
#     233
#     234     @property
#
# ~/.pyenv/versions/3.6.5/envs/bert_client_api/lib/python3.6/site-packages/bert_serving/client/__init__.py in _recv(self, wait_for_req_id)
#     151
#     152                 # receive a response
# --> 153                 response = self.receiver.recv_multipart()
#     154                 request_id = int(response[-1])
#     155
#
# ~/.pyenv/versions/3.6.5/envs/bert_client_api/lib/python3.6/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     473             for any of the reasons :func:`~Socket.recv` might fail
#     474         """
# --> 475         parts = [self.recv(flags, copy=copy, track=track)]
#     476         # have first part already, only loop while more to receive
#     477         while self.getsockopt(zmq.RCVMORE):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# ~/.pyenv/versions/3.6.5/envs/bert_client_api/lib/python3.6/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
list(df.ix[ids]['Tweet Text Size Block'])
